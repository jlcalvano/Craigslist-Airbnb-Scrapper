# %%
import airbnb
import pandas as pd

# %%
results = airbnb.main()
# Out:
# Running...
# https://www.airbnb.com/s/Butler--New-Jersey--United-States/homes?date_picker_type=calendar&query=Butler%2C%20New%20Jersey%2C%20United%20States&checkin=2022-02-01&checkout=2022-03-01&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=weekend_trip&price_max=1400&search_type=filter_change
# Rating : Not Found
# Review : Not Found
# Rating : Not Found
# Review : Not Found
#
# Length of Results: 20
#
#
# Number of Attempts: 1

# %%
pd.json_normalize(results)
# Out:
#           id                                              title  \
# 0   50515640                       Modern room in Butler NJ （5）
# 1   50084451                         Modern Room in Butler NJ 6
# 2   36288134             1 and a half miles from Greenwood Lake
# 3   43463300  Nakomis February 2020 Ground Floor Studio Apar...
# 4   17996538          Room 1-45 minutes from NYC. Near bus stop
# 5   48271683             1 Private Bedroom & 1 private Bathroom
# 6   21565726       Sunny room, excellent location, great price.
# 7   44339582                       #1 - Spacious Beautiful Room
# 8   44540199              Nice Large Room in Boonton/Parsippany
# 9   30532929                  Tu casa-3 Floor-Room 2--sleep two
# 10   3098806         $958 Safe, Quiet, Clean, Wifi, Heat/Air #3
# 11  33117166                Private Room near NYC Bloomfield NJ
# 12  38460234  Cape Nakomis, grey private room, 20 miles from...
# 13  35610460    1 Room In the house with a pool 2 min from lake
# ...
